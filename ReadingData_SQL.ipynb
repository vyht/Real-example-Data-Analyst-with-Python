# %%
# !pip install sqlalchemy

# %%
import pandas as pd
import sqlite3

# %% [markdown]
# ##CONNECT

# %% [markdown]
# *   Database: https://drive.google.com/file/d/1Vtr4YhDJ1TWWC_IJX7oxG7payf-wKQZY/view?usp=drive_link
# *   Muốn làm việc với SQL phải connect

# %%
db = sqlite3.connect('//content/drive/MyDrive/for jobs/GG Colab/Read data/chinook.db')

# %%
cur = db.cursor() #cho phép sử dụng code của sql

# %%
tables = db.execute("SELECT name FROM sqlite_master WHERE type='table';").fetchall()
print(tables) #kiểm tra tên cột
# Out:
# [('albums',), ('sqlite_sequence',), ('artists',), ('customers',), ('employees',), ('genres',), ('invoices',), ('invoice_items',), ('media_types',), ('playlists',), ('playlist_track',), ('tracks',), ('sqlite_stat1',), ('employees2',)]

# %%
cur.execute('SELECT * FROM employees LIMIT 5;')

# %%
results = cur.fetchall()
results
# Out:
# [(1,
#   'Adams',
#   'Andrew',
#   'General Manager',
#   None,
#   '1962-02-18 00:00:00',
#   '2002-08-14 00:00:00',
#   '11120 Jasper Ave NW',
#   'Edmonton',
#   'AB',
#   'Canada',
#   'T5K 2N1',
#   '+1 (780) 428-9482',
#   '+1 (780) 428-3457',
#   'andrew@chinookcorp.com'),
#  (2,
#   'Edwards',
#   'Nancy',
#   'Sales Manager',
#   1,
#   '1958-12-08 00:00:00',
#   '2002-05-01 00:00:00',
#   '825 8 Ave SW',
#   'Calgary',
#   'AB',
#   'Canada',
#   'T2P 2T3',
#   '+1 (403) 262-3443',
#   '+1 (403) 262-3322',
#   'nancy@chinookcorp.com'),
#  (3,
#   'Peacock',
#   'Jane',
#   'Sales Support Agent',
#   2,
#   '1973-08-29 00:00:00',
#   '2002-04-01 00:00:00',
#   '1111 6 Ave SW',
#   'Calgary',
#   'AB',
#   'Canada',
#   'T2P 5M5',
#   '+1 (403) 262-3443',
#   '+1 (403) 262-6712',
#   'jane@chinookcorp.com'),
#  (4,
#   'Park',
#   'Margaret',
#   'Sales Support Agent',
#   2,
#   '1947-09-19 00:00:00',
#   '2003-05-03 00:00:00',
#   '683 10 Street SW',
#   'Calgary',
# ...

# %%
df = pd.DataFrame(results)
df
# Out:
#    0        1         2                    3    4                    5   \
# 0   1    Adams    Andrew      General Manager  NaN  1962-02-18 00:00:00
# 1   2  Edwards     Nancy        Sales Manager  1.0  1958-12-08 00:00:00
# 2   3  Peacock      Jane  Sales Support Agent  2.0  1973-08-29 00:00:00
# 3   4     Park  Margaret  Sales Support Agent  2.0  1947-09-19 00:00:00
# 4   5  Johnson     Steve  Sales Support Agent  2.0  1965-03-03 00:00:00
#
#                     6                    7         8   9       10       11  \
# 0  2002-08-14 00:00:00  11120 Jasper Ave NW  Edmonton  AB  Canada  T5K 2N1
# 1  2002-05-01 00:00:00         825 8 Ave SW   Calgary  AB  Canada  T2P 2T3
# 2  2002-04-01 00:00:00        1111 6 Ave SW   Calgary  AB  Canada  T2P 5M5
# 3  2003-05-03 00:00:00     683 10 Street SW   Calgary  AB  Canada  T2P 5G3
# 4  2003-10-17 00:00:00         7727B 41 Ave   Calgary  AB  Canada  T3B 1Y7
#
#                   12                 13                        14
# ...

# %% [markdown]
# ##READ_SQL

# %%
df = pd.read_sql('select * from employees', db #db để pandas biết câu lệnh này phải chạy trên database nào
                 , parse_dates = ['BirhDate','HireDate']
                 , index_col = ['EmployeeId'])
df.head()
# Out:
#            LastName FirstName                Title  ReportsTo  \
# EmployeeId
# 1             Adams    Andrew      General Manager        NaN
# 2           Edwards     Nancy        Sales Manager        1.0
# 3           Peacock      Jane  Sales Support Agent        2.0
# 4              Park  Margaret  Sales Support Agent        2.0
# 5           Johnson     Steve  Sales Support Agent        2.0
#
#                       BirthDate   HireDate              Address      City  \
# EmployeeId
# 1           1962-02-18 00:00:00 2002-08-14  11120 Jasper Ave NW  Edmonton
# 2           1958-12-08 00:00:00 2002-05-01         825 8 Ave SW   Calgary
# 3           1973-08-29 00:00:00 2002-04-01        1111 6 Ave SW   Calgary
# 4           1947-09-19 00:00:00 2003-05-03     683 10 Street SW   Calgary
# 5           1965-03-03 00:00:00 2003-10-17         7727B 41 Ave   Calgary
#
#            State Country PostalCode              Phone                Fax  \
# EmployeeId
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   EmployeeId  8 non-null      int64
#  1   LastName    8 non-null      object
#  2   FirstName   8 non-null      object
#  3   Title       8 non-null      object
#  4   ReportsTo   7 non-null      float64
#  5   BirthDate   8 non-null      object
#  6   HireDate    8 non-null      object
#  7   Address     8 non-null      object
#  8   City        8 non-null      object
#  9   State       8 non-null      object
#  10  Country     8 non-null      object
#  11  PostalCode  8 non-null      object
#  12  Phone       8 non-null      object
#  13  Fax         8 non-null      object
#  14  Email       8 non-null      object
# dtypes: float64(1), int64(1), object(13)
# memory usage: 1.1+ KB

# %%
df.describe()
# Out:
#        EmployeeId  ReportsTo
# count     8.00000   7.000000
# mean      4.50000   2.857143
# std       2.44949   2.193063
# min       1.00000   1.000000
# 25%       2.75000   1.500000
# 50%       4.50000   2.000000
# 75%       6.25000   4.000000
# max       8.00000   6.000000

# %%
df.shape
# Out:
# (8, 15)

# %%
df.isnull().sum()
# Out:
# LastName      0
# FirstName     0
# Title         0
# ReportsTo     1
# BirthDate     0
# HireDate      0
# Address       0
# City          0
# State         0
# Country       0
# PostalCode    0
# Phone         0
# Fax           0
# Email         0
# dtype: int64

# %%
df['City'] = df['City'].astype('category') #chuyển cột City sang kiểu category của pandas để thuận lợi cho việc truy vấn khi dùng group by, tiết kiệm bộ nhớ, ràng buộc giá trị
df
# Out:
#             LastName FirstName                Title  ReportsTo  \
# EmployeeId
# 1              Adams    Andrew      General Manager        NaN
# 2            Edwards     Nancy        Sales Manager        1.0
# 3            Peacock      Jane  Sales Support Agent        2.0
# 4               Park  Margaret  Sales Support Agent        2.0
# 5            Johnson     Steve  Sales Support Agent        2.0
# 6           Mitchell   Michael           IT Manager        1.0
# 7               King    Robert             IT Staff        6.0
# 8           Callahan     Laura             IT Staff        6.0
#
#                       BirthDate   HireDate                      Address  \
# EmployeeId
# 1           1962-02-18 00:00:00 2002-08-14          11120 Jasper Ave NW
# 2           1958-12-08 00:00:00 2002-05-01                 825 8 Ave SW
# 3           1973-08-29 00:00:00 2002-04-01                1111 6 Ave SW
# 4           1947-09-19 00:00:00 2003-05-03             683 10 Street SW
# ...

# %%
df.dropna()
# Out:
#             LastName FirstName                Title  ReportsTo  \
# EmployeeId
# 2            Edwards     Nancy        Sales Manager        1.0
# 3            Peacock      Jane  Sales Support Agent        2.0
# 4               Park  Margaret  Sales Support Agent        2.0
# 5            Johnson     Steve  Sales Support Agent        2.0
# 6           Mitchell   Michael           IT Manager        1.0
# 7               King    Robert             IT Staff        6.0
# 8           Callahan     Laura             IT Staff        6.0
#
#                       BirthDate   HireDate                      Address  \
# EmployeeId
# 2           1958-12-08 00:00:00 2002-05-01                 825 8 Ave SW
# 3           1973-08-29 00:00:00 2002-04-01                1111 6 Ave SW
# 4           1947-09-19 00:00:00 2003-05-03             683 10 Street SW
# 5           1965-03-03 00:00:00 2003-10-17                 7727B 41 Ave
# 6           1973-07-01 00:00:00 2003-10-17         5827 Bowness Road NW
# ...

# %%
df.to_sql('emplyees2',db,if_exists='replace')
# Out:
# 8
